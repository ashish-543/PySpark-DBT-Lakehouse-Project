# %% [markdown]
# #### This notebook runs all the notebooks in silver layer in incremental order
# - The order of execution is determined by the item index of the list
# - dbutils.notebook.run() waits until the execution of previous notebook and only executes next notebook after the completion of the previous one.
# - timeout_seconds = 0 means, it waits indefinitely until the execution

# %%
notebooks = [
    "/Workspace/Users/ashpnd543@gmail.com/PySpark-DBT-Lakehouse-Project/Notebooks/Silver Layer/CRM/silver_crm_cust_info",
    "/Workspace/Users/ashpnd543@gmail.com/PySpark-DBT-Lakehouse-Project/Notebooks/Silver Layer/CRM/silver_crm_prd_info",
    "/Workspace/Users/ashpnd543@gmail.com/PySpark-DBT-Lakehouse-Project/Notebooks/Silver Layer/CRM/silver_crm_sales_details",
    "/Workspace/Users/ashpnd543@gmail.com/PySpark-DBT-Lakehouse-Project/Notebooks/Silver Layer/ERP/silver_erp_cust_az12",
    "/Workspace/Users/ashpnd543@gmail.com/PySpark-DBT-Lakehouse-Project/Notebooks/Silver Layer/ERP/silver_erp_loc_a101",
    "/Workspace/Users/ashpnd543@gmail.com/PySpark-DBT-Lakehouse-Project/Notebooks/Silver Layer/ERP/silver_erp_px_cat_g1v2"
]

# %%
for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds = 0)
    print(f"{nb} successfully executed")
